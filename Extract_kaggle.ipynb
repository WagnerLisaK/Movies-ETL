# %%
import pandas as pd

# %%
movies_metadata = pd.read_csv('movies_metadata.csv', low_memory=False)
ratings = pd.read_csv('ratings.csv')

# %%
movies_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
movies_metadata.sample(n=5)
# Out:
#        adult                              belongs_to_collection    budget  \
# 11830  False                                                NaN         0
# 22379  False                                                NaN         0
# 31759  False                                                NaN         0
# 6771   False  {'id': 457305, 'name': 'Man of Marble/Iron Col...         0
# 18155  False                                                NaN  66000000
#
#                                                   genres  \
# 11830  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 22379                      [{'id': 18, 'name': 'Drama'}]
# 31759                      [{'id': 18, 'name': 'Drama'}]
# 6771   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 18155  [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...
#
#                             homepage      id    imdb_id original_language  \
# 11830                            NaN    1872  tt0389328                en
# 22379                            NaN  127866  tt2182209                el
# 31759                            NaN  103753  tt1989712                ko
# 6771                             NaN     224  tt0075902                pl
# 18155  http://www.warhorsemovie.com/   57212  tt1568911                en
#
#                              original_title  \
# 11830                    Rise: Blood Hunter
# 22379  Το Αγόρι Τρώει το Φαγητό του Πουλιού
# 31759                               다른 나라에서
# 6771                     Człowiek z marmuru
# 18155                             War Horse
#
#                                                 overview  ... release_date  \
# 11830  A young reporter (Lucy Liu) wakes up and reali...  ...   2007-04-28
# 22379  The astonishing debut feature from Greek filmm...  ...   2012-09-27
# 31759  A three-tiered story centered on a trio of Fre...  ...   2012-05-30
# 6771   Man of Marble is a Polish film about a student...  ...   1977-02-25
# 18155  Follows a young man named Albert and his horse...  ...   2011-12-25
#
#            revenue runtime                                   spoken_languages  \
# 11830          0.0    97.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 22379          0.0    80.0          [{'iso_639_1': 'el', 'name': 'ελληνικά'}]
# 31759          0.0    89.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 6771           0.0   165.0            [{'iso_639_1': 'pl', 'name': 'Polski'}]
# 18155  177584879.0   146.0  [{'iso_639_1': 'th', 'name': 'ภาษาไทย'}, {'iso...
#
#          status                                            tagline  \
# 11830  Released  They didn't leave her alive. They left her UND...
# 22379  Released                                                NaN
# 31759  Released                                                NaN
# 6771   Released                                                NaN
# 18155  Released  Separated by War. Tested by Battle. Bound by F...
#
#                             title  video vote_average vote_count
# 11830          Rise: Blood Hunter  False          4.7       61.0
# 22379  Boy Eating the Bird's Food  False          5.5        4.0
# 31759          In Another Country  False          6.6       30.0
# 6771                Man of Marble  False          5.8       16.0
# 18155                   War Horse  False          7.0     1016.0
#
# [5 rows x 24 columns]

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 11637725  120744     2716     4.5  1168300791
# 24934508  259300     1682     4.5  1115411696
# 2813111    29289     1380     3.0   887712575
# 18361514  190593     3247     3.0   950308021
# 22121702  229780     1242     5.0  1279322884
